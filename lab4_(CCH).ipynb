# %% [markdown]
# <div align="center">
#
# ### Lab 4
#
# # National Tsing Hua University
#
# #### Spring 2024
#
# #### 11220IEEM 513600
#
# #### Deep Learning and Industrial Applications
#
# ## Lab 4: Predicting Stock Price with Deep Learning
#
# </div>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Introduction
#
# In this lab, we explore the application of time-series datasets using Long Short-Term Memory (LSTM) networks, a type of recurrent neural network, to predict stock prices. Specifically, we will use historical price data from Nvidia to forecast the stock's price for the next day based on the prices of the previous N days. This approach is particularly relevant given the volatile nature of stock markets and the increasing reliance on automated trading systems.
#
# ### Objectives
#
# - To understand the fundamentals of LSTM networks and their application in time-series forecasting.
# - To develop a predictive model that can accurately forecast Nvidia's stock price for the next day using historical data.
#
# ### Dataset
#
# The dataset for this lab is from the "Huge Stock Market Dataset" available on Kaggle. This dataset includes daily prices and volumes for all US stocks and ETFs, with a specific focus on Nvidia (NVDA). The dataset features include:
#
# - **Date**: The recorded data points.
# - **Open**: The price at which the stock first traded upon the opening of an exchange on a given trading day.
# - **High**: The highest price at which the stock traded during the trading day.
# - **Low**: The lowest price at which the stock traded during the trading day.
# - **Close**: The price of the stock at closing time.
# - **Volume**: The number of shares or contracts traded in a security or an entire market during a given period.
# - **OpenInt**: The total number of outstanding derivative contracts, like options or futures. [More details here](https://www.kaggle.com/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/discussion/121096)
#
# ### References
#
# - [Huge Stock Market Dataset](https://www.kaggle.com/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs) for the dataset used in this lab.

# %% [markdown]
# ## A. Checking and Preprocessing

# %%
import pandas as pd

df = pd.read_csv('nvda.us.txt')
df
# Out:
#             Date      Open      High       Low     Close    Volume  OpenInt
# 0     1999-01-22    1.6238    1.8092    1.4379    1.5215  18297633        0
# 1     1999-01-25    1.6423    1.6980    1.5215    1.6793   3445279        0
# 2     1999-01-26    1.6980    1.7350    1.5311    1.5494   2320993        0
# 3     1999-01-27    1.5586    1.5957    1.4660    1.5494   1662658        0
# 4     1999-01-28    1.5494    1.5586    1.5311    1.5401   1540110        0
# ...          ...       ...       ...       ...       ...       ...      ...
# 4728  2017-11-06  207.2000  209.9800  206.7000  209.6300   9731783        0
# 4729  2017-11-07  210.5500  212.9000  210.0560  212.0000  10671815        0
# 4730  2017-11-08  211.8500  212.0000  207.2400  209.1600  13033902        0
# 4731  2017-11-09  205.2700  206.3300  200.3700  205.3200  23895006        0
# 4732  2017-11-10  213.0800  218.6700  211.6300  216.1400  31300857        0
#
# [4733 rows x 7 columns]

# %%
plot = df.plot('Date', 'High', figsize=(15, 5))

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'OpenInt'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4733 entries, 0 to 4732
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     4733 non-null   object
#  1   Open     4733 non-null   float64
#  2   High     4733 non-null   float64
#  3   Low      4733 non-null   float64
#  4   Close    4733 non-null   float64
#  5   Volume   4733 non-null   int64
#  6   OpenInt  4733 non-null   int64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 259.0+ KB

# %%
# checking for null values
df.isnull().sum()
# Out:
# Date       0
# Open       0
# High       0
# Low        0
# Close      0
# Volume     0
# OpenInt    0
# dtype: int64

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (4733, 7)

# %%
df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  4733.000000  4733.000000  4733.000000  4733.000000  4.733000e+03
# mean     20.796242    21.157332    20.420417    20.805404  1.615287e+07
# std      30.236284    30.615622    29.792958    30.263705  1.272446e+07
# min       1.298900     1.317500     1.233900     1.261900  0.000000e+00
# 25%       7.988300     8.247900     7.756400     7.978900  8.181100e+06
# 50%      12.963000    13.238000    12.721000    12.990000  1.390271e+07
# 75%      19.141000    19.418000    18.778000    19.106000  2.051602e+07
# max     213.080000   218.670000   211.630000   216.140000  2.496659e+08
#
#        OpenInt
# count   4733.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0

# %% [markdown]
# #### Converting the DataFrame to a NumPy Array

# %%
def create_sequences(input_data, output_data, window_size, step):
    sequences = []
    labels = []
    for i in range(0, len(input_data) - window_size, step):
        sequences.append(input_data[i:(i + window_size)])
        labels.append(output_data[i + window_size])
    return np.array(sequences), np.array(labels)

# %%
import numpy as np
import torch
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt

# Assuming you have a function to create sequences from the data
def create_sequences(features, labels, window_size, step):
    X, y = [], []
    for start in range(0, len(features) - window_size, step):
        end = start + window_size
        X.append(features.iloc[start:end].values)
        y.append(labels.iloc[end])
    return np.array(X), np.array(y)

# Normalization function
def normalize_data(data):
    mean = np.mean(data, axis=(0, 1), keepdims=True)
    std = np.std(data, axis=(0, 1), keepdims=True)
    return (data - mean) / std

# Select features
features = df[['Open', 'High', 'Low', 'Close','Volume']]
labels = df['High'].shift(-1)  # Next day's high price as label

X, y = create_sequences(features, labels, window_size=30, step=15)
# Normalize X
X = normalize_data(X)
print(f'Shape of data X: {X.shape}')
print(f'Shape of data y: {y.shape}')

# split the hold-out tests
ind = np.linspace(0, len(X)-1, num=int(len(X)*0.1), dtype=int) # 10% hold-out
x_test = X[ind]
y_test = y[ind]
all_ind = np.arange(len(X))
remains_ind = np.delete(all_ind, ind)

X = X[remains_ind]
y = y[remains_ind]

# shuffle dataset
ind = np.random.permutation(len(X))
X = X[ind]
y = y[ind]
split_point = int(X.shape[0]*0.8)

x_train = X[:split_point]
y_train = y[:split_point]
x_val = X[split_point:]
y_val = y[split_point:]

print(f'Shape of data x_train: {x_train.shape}')
print(f'Shape of data y_train: {y_train.shape}')
print(f'Shape of data x_val: {x_val.shape}')
print(f'Shape of data y_val: {y_val.shape}')
print(f'Shape of data x_test: {x_test.shape}')
print(f'Shape of data y_test: {y_test.shape}')

# Convert to PyTorch tensors
x_train = torch.from_numpy(x_train).float()
y_train = torch.from_numpy(y_train).float()

x_val = torch.from_numpy(x_val).float()
y_val = torch.from_numpy(y_val).float()

x_test = torch.from_numpy(x_test).float()
y_test = torch.from_numpy(y_test).float()

batch_size = 32

# Create datasets
train_dataset = TensorDataset(x_train, y_train)
val_dataset = TensorDataset(x_val, y_val)
test_dataset = TensorDataset(x_test, y_test)

# Create dataloaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print(f'Number of samples in training and validation are {len(train_loader.dataset)} and {len(val_loader.dataset)}.')
# Out:
# Shape of data X: (314, 30, 5)
# Shape of data y: (314,)
# Shape of data x_train: (226, 30, 5)
# Shape of data y_train: (226,)
# Shape of data x_val: (57, 30, 5)
# Shape of data y_val: (57,)
# Shape of data x_test: (31, 30, 5)
# Shape of data y_test: (31,)
# Number of samples in training and validation are 226 and 57.

# %% [markdown]
# ## B. Defining Neural Networks

# %%
import torch.nn as nn

class LSTMModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, output_dim):
        super().__init__()
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.fc(out[:, -1, :])
        return out

# %% [markdown]
# ## C. Training the Neural Network

# %%
# Check your GPU status.
# !nvidia-smi
# Out:
# Thu May  2 04:03:30 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR
from tqdm.auto import tqdm

train_losses = []
val_losses = []

epochs = 100

model = LSTMModel(input_dim=5, hidden_dim=500, num_layers=2, output_dim=1).cuda()
print(model)

best_val_loss = float('inf')

criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=1e-5)
lr_scheduler = CosineAnnealingLR(optimizer, T_max=epochs, eta_min=0)

for epoch in tqdm(range(epochs)):
    # Training
    model.train()
    total_loss = 0.0

    for features, labels in train_loader:
        features = features.cuda()
        labels = labels.cuda()
        outputs = model(features).squeeze(-1)
        loss = criterion(outputs, labels)
        total_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # Learning rate update
    lr_scheduler.step()

    avg_train_loss = total_loss / len(train_loader)

    # Validation
    model.eval()
    total_val_loss = 0.0

    with torch.no_grad():
        for features, labels in val_loader:
            features = features.cuda()
            labels = labels.cuda()
            outputs = model(features).squeeze(-1)
            loss = criterion(outputs, labels)
            total_val_loss += loss.item()

    avg_val_loss = total_val_loss / len(val_loader)

    # Checkpoint
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        torch.save(model.state_dict(), 'best_model.pth')

    print(f'Epoch {epoch+1}/{epochs}, Train loss: {avg_train_loss:.4f}, Val loss: {avg_val_loss:.4f}, Best Val loss: {best_val_loss:.4f}')

    # Store performance
    train_losses.append(avg_train_loss)
    val_losses.append(avg_val_loss)
# Out:
# LSTMModel(
#   (lstm): LSTM(5, 500, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=500, out_features=1, bias=True)
# )
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 1/100, Train loss: 1169.5355, Val loss: 1595.8116, Best Val loss: 1595.8116
# Epoch 2/100, Train loss: 1234.3793, Val loss: 1595.0755, Best Val loss: 1595.0755
# Epoch 3/100, Train loss: 1179.1482, Val loss: 1594.3442, Best Val loss: 1594.3442
# Epoch 4/100, Train loss: 1188.4327, Val loss: 1593.6187, Best Val loss: 1593.6187
# Epoch 5/100, Train loss: 1185.0160, Val loss: 1592.8358, Best Val loss: 1592.8358
# Epoch 6/100, Train loss: 1223.8885, Val loss: 1592.0532, Best Val loss: 1592.0532
# Epoch 7/100, Train loss: 1162.6213, Val loss: 1591.2334, Best Val loss: 1591.2334
# Epoch 8/100, Train loss: 1176.7539, Val loss: 1590.3618, Best Val loss: 1590.3618
# Epoch 9/100, Train loss: 1158.7273, Val loss: 1589.4844, Best Val loss: 1589.4844
# Epoch 10/100, Train loss: 1164.2378, Val loss: 1588.4429, Best Val loss: 1588.4429
# Epoch 11/100, Train loss: 1173.2110, Val loss: 1587.4002, Best Val loss: 1587.4002
# Epoch 12/100, Train loss: 1234.6175, Val loss: 1586.1343, Best Val loss: 1586.1343
# Epoch 13/100, Train loss: 1162.6315, Val loss: 1584.6117, Best Val loss: 1584.6117
# Epoch 14/100, Train loss: 1162.0500, Val loss: 1582.8607, Best Val loss: 1582.8607
# Epoch 15/100, Train loss: 1203.8039, Val loss: 1580.7112, Best Val loss: 1580.7112
# Epoch 16/100, Train loss: 2872.0499, Val loss: 1578.0976, Best Val loss: 1578.0976
# Epoch 17/100, Train loss: 1167.3908, Val loss: 1575.0905, Best Val loss: 1575.0905
# Epoch 18/100, Train loss: 1173.3092, Val loss: 1572.2173, Best Val loss: 1572.2173
# Epoch 19/100, Train loss: 1154.5516, Val loss: 1568.6638, Best Val loss: 1568.6638
# Epoch 20/100, Train loss: 1154.2941, Val loss: 1564.6300, Best Val loss: 1564.6300
# Epoch 21/100, Train loss: 1153.8933, Val loss: 1558.9760, Best Val loss: 1558.9760
# Epoch 22/100, Train loss: 1144.8530, Val loss: 1551.7961, Best Val loss: 1551.7961
# Epoch 23/100, Train loss: 1152.1677, Val loss: 1540.9822, Best Val loss: 1540.9822
# Epoch 24/100, Train loss: 1189.5726, Val loss: 1527.4352, Best Val loss: 1527.4352
# Epoch 25/100, Train loss: 1114.8152, Val loss: 1509.3623, Best Val loss: 1509.3623
# Epoch 26/100, Train loss: 1220.4789, Val loss: 1488.8349, Best Val loss: 1488.8349
# Epoch 27/100, Train loss: 1089.7304, Val loss: 1466.9746, Best Val loss: 1466.9746
# Epoch 28/100, Train loss: 1156.5327, Val loss: 1445.3640, Best Val loss: 1445.3640
# Epoch 29/100, Train loss: 1062.1660, Val loss: 1420.4936, Best Val loss: 1420.4936
# Epoch 30/100, Train loss: 1086.5140, Val loss: 1394.0124, Best Val loss: 1394.0124
# Epoch 31/100, Train loss: 1157.5692, Val loss: 1359.5802, Best Val loss: 1359.5802
# Epoch 32/100, Train loss: 1011.9143, Val loss: 1321.8913, Best Val loss: 1321.8913
# Epoch 33/100, Train loss: 954.2402, Val loss: 1292.7912, Best Val loss: 1292.7912
# Epoch 34/100, Train loss: 932.9731, Val loss: 1275.4320, Best Val loss: 1275.4320
# Epoch 35/100, Train loss: 1120.7806, Val loss: 1264.1684, Best Val loss: 1264.1684
# Epoch 36/100, Train loss: 1500.7157, Val loss: 1255.2836, Best Val loss: 1255.2836
# Epoch 37/100, Train loss: 925.9956, Val loss: 1247.5369, Best Val loss: 1247.5369
# Epoch 38/100, Train loss: 900.1574, Val loss: 1241.3473, Best Val loss: 1241.3473
# Epoch 39/100, Train loss: 902.2275, Val loss: 1236.3233, Best Val loss: 1236.3233
# Epoch 40/100, Train loss: 895.7069, Val loss: 1231.6930, Best Val loss: 1231.6930
# Epoch 41/100, Train loss: 891.2693, Val loss: 1227.6131, Best Val loss: 1227.6131
# Epoch 42/100, Train loss: 915.0990, Val loss: 1223.7496, Best Val loss: 1223.7496
# Epoch 43/100, Train loss: 887.2622, Val loss: 1220.2811, Best Val loss: 1220.2811
# Epoch 44/100, Train loss: 885.1320, Val loss: 1217.1362, Best Val loss: 1217.1362
# Epoch 45/100, Train loss: 877.1649, Val loss: 1214.2850, Best Val loss: 1214.2850
# Epoch 46/100, Train loss: 877.9145, Val loss: 1211.7986, Best Val loss: 1211.7986
# Epoch 47/100, Train loss: 903.4663, Val loss: 1209.5343, Best Val loss: 1209.5343
# Epoch 48/100, Train loss: 891.5078, Val loss: 1207.4428, Best Val loss: 1207.4428
# Epoch 49/100, Train loss: 879.9374, Val loss: 1205.3763, Best Val loss: 1205.3763
# Epoch 50/100, Train loss: 868.6300, Val loss: 1203.5326, Best Val loss: 1203.5326
# Epoch 51/100, Train loss: 866.9726, Val loss: 1201.8621, Best Val loss: 1201.8621
# Epoch 52/100, Train loss: 873.0339, Val loss: 1200.2649, Best Val loss: 1200.2649
# Epoch 53/100, Train loss: 902.0161, Val loss: 1198.7873, Best Val loss: 1198.7873
# Epoch 54/100, Train loss: 2812.7858, Val loss: 1197.1568, Best Val loss: 1197.1568
# Epoch 55/100, Train loss: 865.3444, Val loss: 1195.3065, Best Val loss: 1195.3065
# Epoch 56/100, Train loss: 869.9754, Val loss: 1193.8233, Best Val loss: 1193.8233
# Epoch 57/100, Train loss: 865.1097, Val loss: 1192.5407, Best Val loss: 1192.5407
# Epoch 58/100, Train loss: 864.8318, Val loss: 1191.2892, Best Val loss: 1191.2892
# Epoch 59/100, Train loss: 865.9921, Val loss: 1190.1054, Best Val loss: 1190.1054
# Epoch 60/100, Train loss: 892.2577, Val loss: 1189.0182, Best Val loss: 1189.0182
# Epoch 61/100, Train loss: 856.5520, Val loss: 1187.9738, Best Val loss: 1187.9738
# Epoch 62/100, Train loss: 858.9303, Val loss: 1187.0991, Best Val loss: 1187.0991
# Epoch 63/100, Train loss: 859.9903, Val loss: 1186.2530, Best Val loss: 1186.2530
# Epoch 64/100, Train loss: 857.7138, Val loss: 1185.4969, Best Val loss: 1185.4969
# Epoch 65/100, Train loss: 854.4143, Val loss: 1184.7738, Best Val loss: 1184.7738
# Epoch 66/100, Train loss: 855.1014, Val loss: 1184.1300, Best Val loss: 1184.1300
# Epoch 67/100, Train loss: 1040.7650, Val loss: 1183.5458, Best Val loss: 1183.5458
# Epoch 68/100, Train loss: 1042.7919, Val loss: 1182.9422, Best Val loss: 1182.9422
# Epoch 69/100, Train loss: 853.7566, Val loss: 1182.3517, Best Val loss: 1182.3517
# Epoch 70/100, Train loss: 2009.2282, Val loss: 1181.8246, Best Val loss: 1181.8246
# Epoch 71/100, Train loss: 852.7450, Val loss: 1181.2424, Best Val loss: 1181.2424
# Epoch 72/100, Train loss: 854.0045, Val loss: 1180.8221, Best Val loss: 1180.8221
# Epoch 73/100, Train loss: 1251.7678, Val loss: 1180.4322, Best Val loss: 1180.4322
# Epoch 74/100, Train loss: 865.1826, Val loss: 1180.0322, Best Val loss: 1180.0322
# Epoch 75/100, Train loss: 2367.2143, Val loss: 1179.6758, Best Val loss: 1179.6758
# Epoch 76/100, Train loss: 856.8198, Val loss: 1179.2825, Best Val loss: 1179.2825
# Epoch 77/100, Train loss: 854.1137, Val loss: 1179.0021, Best Val loss: 1179.0021
# Epoch 78/100, Train loss: 852.6413, Val loss: 1178.7584, Best Val loss: 1178.7584
# Epoch 79/100, Train loss: 850.3677, Val loss: 1178.5481, Best Val loss: 1178.5481
# Epoch 80/100, Train loss: 856.6167, Val loss: 1178.3613, Best Val loss: 1178.3613
# Epoch 81/100, Train loss: 850.5098, Val loss: 1178.1886, Best Val loss: 1178.1886
# Epoch 82/100, Train loss: 876.8480, Val loss: 1178.0450, Best Val loss: 1178.0450
# Epoch 83/100, Train loss: 851.2873, Val loss: 1177.9161, Best Val loss: 1177.9161
# Epoch 84/100, Train loss: 2004.1079, Val loss: 1177.7858, Best Val loss: 1177.7858
# Epoch 85/100, Train loss: 1976.2818, Val loss: 1177.6360, Best Val loss: 1177.6360
# Epoch 86/100, Train loss: 849.0790, Val loss: 1177.4962, Best Val loss: 1177.4962
# Epoch 87/100, Train loss: 876.0788, Val loss: 1177.4005, Best Val loss: 1177.4005
# Epoch 88/100, Train loss: 848.8524, Val loss: 1177.3227, Best Val loss: 1177.3227
# Epoch 89/100, Train loss: 852.7788, Val loss: 1177.2635, Best Val loss: 1177.2635
# Epoch 90/100, Train loss: 851.5140, Val loss: 1177.2147, Best Val loss: 1177.2147
# Epoch 91/100, Train loss: 866.5844, Val loss: 1177.1752, Best Val loss: 1177.1752
# Epoch 92/100, Train loss: 862.9150, Val loss: 1177.1406, Best Val loss: 1177.1406
# Epoch 93/100, Train loss: 849.1421, Val loss: 1177.1152, Best Val loss: 1177.1152
# Epoch 94/100, Train loss: 852.6590, Val loss: 1177.0947, Best Val loss: 1177.0947
# Epoch 95/100, Train loss: 2009.2657, Val loss: 1177.0784, Best Val loss: 1177.0784
# Epoch 96/100, Train loss: 1415.7490, Val loss: 1177.0635, Best Val loss: 1177.0635
# Epoch 97/100, Train loss: 1408.4433, Val loss: 1177.0542, Best Val loss: 1177.0542
# Epoch 98/100, Train loss: 850.1478, Val loss: 1177.0491, Best Val loss: 1177.0491
# Epoch 99/100, Train loss: 855.2605, Val loss: 1177.0472, Best Val loss: 1177.0472
# Epoch 100/100, Train loss: 849.1266, Val loss: 1177.0468, Best Val loss: 1177.0468

# %% [markdown]
# #### Visualizing the model performance

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(train_losses)
plt.plot(val_losses)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train', 'Val'])

plt.show()

# %% [markdown]
# ## D. Evaluating Your Trained Model

# %%
# Load the trained weights
model.load_state_dict(torch.load('best_model.pth'))

# Set the model to evaluation mode
model.eval()

test_correct = 0
test_total = 0

pred_value = []
actual_value = []

with torch.no_grad():
    for features, labels in test_loader:
        features = features.cuda()
        outputs = model(features).squeeze(-1)
        pred_value.append(outputs.cpu())
        actual_value.append(labels)

pred_value = torch.cat(pred_value)
actual_value = torch.cat(actual_value)

# %%
plt.figure(figsize=(10, 5))
plt.plot(pred_value[:])
plt.plot(actual_value[:])
plt.xlabel('Day')
plt.ylabel('Price')
plt.legend(['Pred', 'Actual'])

plt.show()
